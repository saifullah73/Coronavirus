# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd ML Project
# !ls
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content/gdrive/My Drive
# /content/gdrive/My Drive/ML Project
# 'ML Project.ipynb'

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/ML Project/.git/

# %%
# !git remote add origin https://saifullah73:Resident-evil6@github.com/saifullah73/Coronavirus.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://saifullah73:Resident-evil6@github.com/saifullah73/Coronavirus.git (fetch)
# origin	https://saifullah73:Resident-evil6@github.com/saifullah73/Coronavirus.git (push)
# fatal: Couldn't find remote ref master

# %%
# !git config --global user.email 'saifullahkhaliq@gmail.com'
# !git config --global user.name 'saifullah'

# %%
# !git pull origin master
# Out:
# From https://github.com/saifullah73/Coronavirus
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git add --all
# !git commit -m 'First Commit'
# Out:
# [master (root-commit) e4e8ea1] First Commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 ML project.ipynb
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.23 KiB | 571.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/saifullah73/Coronavirus.git
#  * [new branch]      master -> master
